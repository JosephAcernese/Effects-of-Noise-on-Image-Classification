rf_f_test_blur = {1: 0.7333333333333333, 2: 0.7375, 3: 0.75, 4: 0.7375, 5: 0.7166666666666667, 6: 0.6791666666666667, 7: 0.6666666666666666, 8: 0.6625, 9: 0.6541666666666667, 10: 0.6541666666666667}
rf_f_train_blur = {1: 0.9791666666666666, 2: 0.9322916666666666, 3: 0.928125, 4: 0.9, 5: 0.865625, 6: 0.809375, 7: 0.7979166666666667, 8: 0.7802083333333333, 9: 0.7708333333333333, 10: 0.7583333333333333}

rf_accuracy_test_sp = {0: 0.7333333333333333, 0.05: 0.75, 0.1: 0.7291666666666666, 0.15: 0.725, 0.2: 0.7458333333333333, 0.25: 0.7375, 0.3: 0.7, 0.35: 0.6708333333333333, 0.4: 0.675, 0.45: 0.6, 0.5: 0.49583333333333335}
rf_accuracy_train_sp = {0: 0.9791666666666666, 0.05: 0.9760416666666667, 0.1: 0.9708333333333333, 0.15: 0.9666666666666667, 0.2: 0.953125, 0.25: 0.9427083333333334, 0.3: 0.9333333333333333, 0.35: 0.9052083333333333, 0.4: 0.86875, 0.45: 0.7885416666666667, 0.5: 0.6625}
rf_f_test_sp = {0: 0.7333333333333333, 0.05: 0.75, 0.1: 0.7291666666666665, 0.15: 0.7250000000000001, 0.2: 0.7458333333333332, 0.25: 0.7375, 0.3: 0.7, 0.35: 0.6708333333333333, 0.4: 0.675, 0.45: 0.6, 0.5: 0.49583333333333335}
rf_f_train_sp ={0: 0.9791666666666666, 0.05: 0.9760416666666667, 0.1: 0.9708333333333333, 0.15: 0.9666666666666667, 0.2: 0.953125, 0.25: 0.9427083333333334, 0.3: 0.9333333333333333, 0.35: 0.9052083333333333, 0.4: 0.86875, 0.45: 0.7885416666666668, 0.5: 0.6625}

# %%
# Plot svm w/ gaussian
plt.ylim(0,1.02)
plt.grid()
plt.title("SVM with Gaussian Noise")
plt.xlabel("Standard Deviation (σ)")
plt.ylabel("F-Score")
plt.xticks(list(svm_test_f_gaussian.keys()))
plt.plot(list(svm_test_f_gaussian.keys()),list(svm_test_f_gaussian.values()),**{'marker':'o'})
plt.plot(list(svm_train_f_gaussian.keys()),list(svm_train_f_gaussian.values()),**{'marker':'o'})
plt.legend(["Testing","Training"])
plt.show()

# %%
# Plot svm w/ sp
plt.ylim(0,1.02)
plt.grid()
plt.title("SVM with Impulse Noise")
plt.xlabel("Rate of Noise (R)")
plt.ylabel("F-Score")
plt.xticks(list(svm_test_f_sp.keys()))
plt.plot(list(svm_test_f_sp.keys()),list(svm_test_f_sp.values()),**{'marker':'o'})
plt.plot(list(svm_train_f_sp.keys()),list(svm_train_f_sp.values()),**{'marker':'o'})
plt.legend(["Testing","Training"])
plt.show()

# %%
# Plot svm w/ blur
plt.ylim(0,1.02)
plt.grid()
plt.title("SVM with Blur")
plt.xlabel("Kernel Size (K)")
plt.ylabel("F-Score")
plt.xticks(list(svm_test_f_blur.keys()))
plt.plot(list(svm_test_f_blur.keys()),list(svm_test_f_blur.values()),**{'marker':'o'})
plt.plot(list(svm_train_f_blur.keys()),list(svm_train_f_blur.values()),**{'marker':'o'})
plt.legend(["Testing","Training"])
plt.show()

# %%
# Plot svm w/ gaussian
plt.ylim(0,1.02)
plt.grid()
plt.title("KNN with Gaussian Noise")
plt.xlabel("Standard Deviation (σ)")
plt.ylabel("F-Score")
plt.xticks(list(knn_test_f_gaussian.keys()))
plt.plot(list(knn_test_f_gaussian.keys()),list(knn_test_f_gaussian.values()),**{'marker':'o'})
plt.plot(list(knn_train_f_gaussian.keys()),list(knn_train_f_gaussian.values()),**{'marker':'o'})
plt.legend(["Testing","Training"])
plt.show()

# %%
# Plot svm w/ sp
plt.ylim(0,1.02)
plt.grid()
plt.title("KNN with Impulse Noise")
plt.xlabel("Rate of Noise (R)")
plt.ylabel("F-Score")
plt.xticks(list(knn_test_f_sp.keys()))
plt.plot(list(knn_test_f_sp.keys()),list(knn_test_f_sp.values()),**{'marker':'o'})
plt.plot(list(knn_train_f_sp.keys()),list(knn_train_f_sp.values()),**{'marker':'o'})
plt.legend(["Testing","Training"])
plt.show()

# %%
# Plot svm w/ blur
plt.ylim(0,1.02)
plt.grid()
plt.title("KNN with Blur")
plt.xlabel("Kernel Size (K)")
plt.ylabel("F-Score")
plt.xticks(list(knn_test_f_blur.keys()))
plt.plot(list(knn_test_f_blur.keys()),list(knn_test_f_blur.values()),**{'marker':'o'})
plt.plot(list(knn_train_f_blur.keys()),list(knn_train_f_blur.values()),**{'marker':'o'})
plt.legend(["Testing","Training"])
plt.show()

# %%
# Plot nb w/ gaussian
plt.ylim(0,1.02)
plt.grid()
plt.title("Naive Bayes with Gaussian Noise")
plt.xlabel("Standard Deviation (σ)")
plt.ylabel("F-Score")
plt.xticks(list(nb_test_f_gaussian.keys()))
plt.plot(list(nb_test_f_gaussian.keys()),list(nb_test_f_gaussian.values()),**{'marker':'o'})
plt.plot(list(nb_train_f_gaussian.keys()),list(nb_train_f_gaussian.values()),**{'marker':'o'})
plt.legend(["Testing","Training"])
plt.show()

# %%
# Plot nb w/ impulse
plt.ylim(0,1.02)
plt.grid()
plt.title("Naive Bayes with Impulse Noise")
plt.xlabel("Rate of Noise (R)")
plt.ylabel("F-Score")
plt.xticks(list(nb_test_f_sp.keys()))
plt.plot(list(nb_test_f_sp.keys()),list(nb_test_f_sp.values()),**{'marker':'o'})
plt.plot(list(nb_train_f_sp.keys()),list(nb_train_f_sp.values()),**{'marker':'o'})
plt.legend(["Testing","Training"])
plt.show()

# %%
# Plot nb w/ blur
plt.ylim(0,1.02)
plt.grid()
plt.title("Naive Bayes with Blur")
plt.xlabel("Kernel Size (K)")
plt.ylabel("F-Score")
plt.xticks(list(nb_test_f_blur.keys()))
plt.plot(list(nb_test_f_blur.keys()),list(nb_test_f_blur.values()),**{'marker':'o'})
plt.plot(list(nb_train_f_blur.keys()),list(nb_train_f_blur.values()),**{'marker':'o'})
plt.legend(["Testing","Training"])
plt.show()

# %%
# Plot rf w/ gaussian
plt.ylim(0,1.02)
plt.grid()
plt.title("Random Forest with Gaussian Noise")
plt.xlabel("Standard Deviation (σ)")
plt.ylabel("F-Score")
plt.xticks(list(rf_f_test_gaussian.keys()))
plt.plot(list(rf_f_test_gaussian.keys()),list(rf_f_test_gaussian.values()),**{'marker':'o'})
plt.plot(list(rf_f_train_gaussian.keys()),list(rf_f_train_gaussian.values()),**{'marker':'o'})
plt.legend(["Testing","Training"])
plt.show()

# %%
# Plot rf w/ sp
plt.ylim(0,1.02)
plt.grid()
plt.title("Random Forest with Impulse Noise")
plt.xlabel("Rate of Noise (R)")
plt.ylabel("F-Score")
plt.xticks(list(rf_f_test_sp.keys()))
plt.plot(list(rf_f_test_sp.keys()),list(rf_f_test_sp.values()),**{'marker':'o'})
plt.plot(list(rf_f_train_sp.keys()),list(rf_f_train_sp.values()),**{'marker':'o'})
plt.legend(["Testing","Training"])
plt.show()

# %%
# Plot rf w/ blur
plt.ylim(0,1.02)
plt.grid()
plt.title("Random Forest with Blur")
plt.xlabel("Kernel Size (K)")
plt.ylabel("F-Score")
plt.xticks(list(rf_f_test_blur.keys()))
plt.plot(list(rf_f_test_blur.keys()),list(rf_f_test_blur.values()),**{'marker':'o'})
plt.plot(list(rf_f_train_blur.keys()),list(rf_f_train_blur.values()),**{'marker':'o'})
plt.legend(["Testing","Training"])
plt.show()

# %%
# GAUSSIAN TRAINING SCORES

plt.ylim(0,1.02)
plt.grid()
plt.title("Guassian Training Scores")
plt.xlabel("Standard Deviation (σ)")
plt.ylabel("F-Score")
plt.xticks(list(rf_f_train_gaussian.keys()))

plt.plot(list(knn_train_f_gaussian.keys()),list(knn_train_f_gaussian.values()),**{'marker':'o'})
plt.plot(list(svm_train_f_gaussian.keys()),list(svm_train_f_gaussian.values()),**{'marker':'o'})
plt.plot(list(nb_train_f_gaussian.keys()),list(nb_train_f_gaussian.values()),**{'marker':'o'})
plt.plot(list(rf_f_train_gaussian.keys()),list(rf_f_train_gaussian.values()),**{'marker':'o'})
plt.legend(["KNN","SVM","Naive Bayes","Random Forest"])

plt.show()

# %%
# GAUSSIAN TESTING SCORES

plt.ylim(0,1.02)
plt.grid()
plt.title("Guassian Testing Scores")
plt.xlabel("Standard Deviation (σ)")
plt.ylabel("F-Score")
plt.xticks(list(rf_f_test_gaussian.keys()))

plt.plot(list(knn_test_f_gaussian.keys()),list(knn_test_f_gaussian.values()),**{'marker':'o'})
plt.plot(list(svm_test_f_gaussian.keys()),list(svm_test_f_gaussian.values()),**{'marker':'o'})
plt.plot(list(nb_test_f_gaussian.keys()),list(nb_test_f_gaussian.values()),**{'marker':'o'})
plt.plot(list(rf_f_test_gaussian.keys()),list(rf_f_test_gaussian.values()),**{'marker':'o'})
plt.legend(["KNN","SVM","Naive Bayes","Random Forest"])

plt.show()

# %%
# IMPULSE TRAINING SCORES

plt.ylim(0,1.02)
plt.grid()
plt.title("Impulse Training Scores")
plt.xlabel("Rate of Noise (R)")
plt.ylabel("F-Score")
plt.xticks(list(rf_f_train_sp.keys()))

plt.plot(list(knn_train_f_sp.keys()),list(knn_train_f_sp.values()),**{'marker':'o'})
plt.plot(list(svm_train_f_sp.keys()),list(svm_train_f_sp.values()),**{'marker':'o'})
plt.plot(list(nb_train_f_sp.keys()),list(nb_train_f_sp.values()),**{'marker':'o'})
plt.plot(list(rf_f_train_sp.keys()),list(rf_f_train_sp.values()),**{'marker':'o'})
plt.legend(["KNN","SVM","Naive Bayes","Random Forest"])

plt.show()

# %%
# IMPULSE TESTING SCORES

plt.ylim(0,1.02)
plt.grid()
plt.title("Impulse Testing Scores")
plt.xlabel("Rate of Noise (R)")
plt.ylabel("F-Score")
plt.xticks(list(rf_f_test_sp.keys()))

plt.plot(list(knn_test_f_sp.keys()),list(knn_test_f_sp.values()),**{'marker':'o'})
plt.plot(list(svm_test_f_sp.keys()),list(svm_test_f_sp.values()),**{'marker':'o'})
plt.plot(list(nb_test_f_sp.keys()),list(nb_test_f_sp.values()),**{'marker':'o'})
plt.plot(list(rf_f_test_sp.keys()),list(rf_f_test_sp.values()),**{'marker':'o'})
plt.legend(["KNN","SVM","Naive Bayes","Random Forest"])

plt.show()

# %%
# IMPULSE TRAINING SCORES

plt.ylim(0,1.02)
plt.grid()
plt.title("Blur Training Scores")
plt.xlabel("Kernel Size (K)")
plt.ylabel("F-Score")
plt.xticks(list(rf_f_train_blur.keys()))

plt.plot(list(knn_train_f_blur.keys()),list(knn_train_f_blur.values()),**{'marker':'o'})
plt.plot(list(svm_train_f_blur.keys()),list(svm_train_f_blur.values()),**{'marker':'o'})
plt.plot(list(nb_train_f_blur.keys()),list(nb_train_f_blur.values()),**{'marker':'o'})
plt.plot(list(rf_f_train_blur.keys()),list(rf_f_train_blur.values()),**{'marker':'o'})
plt.legend(["KNN","SVM","Naive Bayes","Random Forest"])

plt.show()

# %%
# BLUR TESTING SCORES

plt.ylim(0,1.02)
plt.grid()
plt.title("Blur Testing Scores")
plt.xlabel("Kernel Size (K)")
plt.ylabel("F-Score")
plt.xticks(list(rf_f_test_blur.keys()))

plt.plot(list(knn_test_f_blur.keys()),list(knn_test_f_blur.values()),**{'marker':'o'})
plt.plot(list(svm_test_f_blur.keys()),list(svm_test_f_blur.values()),**{'marker':'o'})
plt.plot(list(nb_test_f_blur.keys()),list(nb_test_f_blur.values()),**{'marker':'o'})
plt.plot(list(rf_f_test_blur.keys()),list(rf_f_test_blur.values()),**{'marker':'o'})
plt.legend(["KNN","SVM","Naive Bayes","Random Forest"])

plt.show()

# %%
# and if anybody has time to calculate the ELA for each graph and record them with the graphs on page 
# 15 onward that would be great. the formula is just (1.0 - accuracy at final noise level)/(accuracy at 0% noise)

svm_test_acc_gaussian = {0: 0.7875, 0.01: 0.7833333333333333, 0.02: 0.7875, 0.03: 0.7916666666666666, 0.04: 0.7833333333333333, 0.05: 0.7666666666666667, 0.06: 0.75, 0.07: 0.7291666666666666, 0.08: 0.7041666666666667, 0.09: 0.6333333333333333, 0.1: 0.6}
svm_train_acc_gaussian = {0: 1.0, 0.01: 1.0, 0.02: 1.0, 0.03: 1.0, 0.04: 1.0, 0.05: 1.0, 0.06: 1.0, 0.07: 1.0, 0.08: 0.9927083333333333, 0.09: 0.9604166666666667, 0.1: 0.9083333333333333}

svm_test_acc_sp = {0: 0.7875, 0.05: 0.7875, 0.1: 0.775, 0.15: 0.75, 0.2: 0.6666666666666666, 0.25: 0.5083333333333333, 0.3: 0.2833333333333333, 0.35: 0.15416666666666667, 0.4: 0.09583333333333334, 0.45: 0.08333333333333333, 0.5: 0.08333333333333333}
svm_train_acc_sp = {0: 1.0, 0.05: 1.0, 0.1: 1.0, 0.15: 0.9989583333333333, 0.2: 0.9697916666666667, 0.25: 0.759375, 0.3: 0.409375, 0.35: 0.15104166666666666, 0.4: 0.09270833333333334, 0.45: 0.08333333333333333, 0.5: 0.08333333333333333}

svm_test_acc_blur = {1: 0.7875, 2: 0.7916666666666666, 3: 0.7916666666666666, 4: 0.7833333333333333, 5: 0.7833333333333333, 6: 0.7791666666666667, 7: 0.7833333333333333, 8: 0.775, 9: 0.7708333333333334, 10: 0.7541666666666667}
svm_train_acc_blur = {1: 1.0, 2: 1.0, 3: 0.9989583333333333, 4: 0.9989583333333333, 5: 0.9979166666666667, 6: 0.996875, 7: 0.9947916666666666, 8: 0.9895833333333334, 9: 0.9833333333333333, 10: 0.96875}
print("SVM")
print("Gaussian")
print("Train: ",(1-svm_train_acc_gaussian[0.1])/svm_train_acc_gaussian[0])
print("Test: ", (1-svm_test_acc_gaussian[0.1])/svm_test_acc_gaussian[0])
print()
print("Impulse")
print("Train: ",(1-svm_train_acc_sp[0.5])/svm_train_acc_sp[0])
print("Test: ",(1-svm_test_acc_sp[0.5])/svm_test_acc_sp[0])
print()
print("Blur")
print("Train: ",(1-svm_train_acc_blur[10])/svm_train_acc_blur[1])
print("Test: ",(1-svm_test_acc_blur[10])/svm_test_acc_blur[1])
# Out:
# SVM
# Gaussian
# Train:  0.09166666666666667
# Test:  0.507936507936508
#
# Impulse
# Train:  0.9166666666666666
# Test:  1.164021164021164
#
# Blur
# Train:  0.03125
# Test:  0.3121693121693122

# %%
knn_test_acc_gaussian = {0: 0.6583333333333333, 0.01: 0.8333333333333334, 0.02: 0.8333333333333334, 0.03: 0.8291666666666667, 0.04: 0.8291666666666667, 0.05: 0.8208333333333333, 0.06: 0.8125, 0.07: 0.7958333333333333, 0.08: 0.7916666666666666, 0.09: 0.7875, 0.1: 0.7708333333333334}
knn_train_acc_gaussian = {0: 0.865625, 0.01: 0.8229166666666666, 0.02: 0.8135416666666667, 0.03: 0.8114583333333333, 0.04: 0.80625, 0.05: 0.7958333333333333, 0.06: 0.784375, 0.07: 0.7770833333333333, 0.08: 0.7729166666666667, 0.09: 0.7625, 0.1: 0.75}

knn_test_acc_blur = {1: 0.6583333333333333, 2: 0.8333333333333334, 3: 0.8333333333333334, 4: 0.8375, 5: 0.8333333333333334, 6: 0.8375, 7: 0.8291666666666667, 8: 0.8291666666666667, 9: 0.8125, 10: 0.8083333333333333}
knn_train_acc_blur = {1: 0.865625, 2: 0.815625, 3: 0.8208333333333333, 4: 0.815625, 5: 0.815625, 6: 0.815625, 7: 0.8125, 8: 0.8114583333333333, 9: 0.8083333333333333, 10: 0.8083333333333333}

knn_test_acc_sp = {0: 0.6583333333333333, 0.05: 0.8291666666666667, 0.1: 0.8333333333333334, 0.15: 0.8125, 0.2: 0.7791666666666667, 0.25: 0.7541666666666667, 0.3: 0.7083333333333334, 0.35: 0.6416666666666667, 0.4: 0.5583333333333333, 0.45: 0.4583333333333333, 0.5: 0.3333333333333333}
knn_train_acc_sp = {0: 0.865625, 0.05: 0.815625, 0.1: 0.796875, 0.15: 0.7854166666666667, 0.2: 0.7572916666666667, 0.25: 0.7083333333333334, 0.3: 0.665625, 0.35: 0.5927083333333333, 0.4: 0.490625, 0.45: 0.40729166666666666, 0.5: 0.30416666666666664}

print("Gaussian")
print("Train: ",(1-knn_train_acc_gaussian[0.1])/knn_train_acc_gaussian[0])
print("Test: ", (1-knn_test_acc_gaussian[0.1])/knn_test_acc_gaussian[0])
print()
print("Impulse")
print("Train: ",(1-knn_train_acc_sp[0.5])/knn_train_acc_sp[0])
print("Test: ",(1-knn_test_acc_sp[0.5])/knn_test_acc_sp[0])
print()
print("Blur")
print("Train: ",(1-knn_train_acc_blur[10])/knn_train_acc_blur[1])
print("Test: ",(1-knn_test_acc_blur[10])/knn_test_acc_blur[1])
# Out:
# Gaussian
# Train:  0.2888086642599278
# Test:  0.3481012658227848
#
# Impulse
# Train:  0.8038507821901324
# Test:  1.0126582278481013
#
# Blur
# Train:  0.2214199759326113
# Test:  0.2911392405063291

# %%
nb_test_acc_gaussian =  {0: 0.5625, 0.01: 0.5708333333333333, 0.02: 0.5708333333333333, 0.03: 0.5625, 0.04: 0.5666666666666667, 0.05: 0.5625, 0.06: 0.55, 0.07: 0.5583333333333333, 0.08: 0.55, 0.09: 0.55, 0.1: 0.5375}
nb_train_acc_gaussian =  {0: 0.6166666666666667, 0.01: 0.61875, 0.02: 0.61875, 0.03: 0.6208333333333333, 0.04: 0.621875, 0.05: 0.6177083333333333, 0.06: 0.6145833333333334, 0.07: 0.6083333333333333, 0.08: 0.60625, 0.09: 0.6083333333333333, 0.1: 0.6}

nb_test_acc_blur =  {1: 0.5625, 2: 0.5625, 3: 0.5625, 4: 0.5625, 5: 0.5625, 6: 0.5583333333333333, 7: 0.5375, 8: 0.5291666666666667, 9: 0.5166666666666667, 10: 0.5083333333333333}
nb_train_acc_blur =  {1: 0.6166666666666667, 2: 0.61875, 3: 0.6135416666666667, 4: 0.6145833333333334, 5: 0.60625, 6: 0.6010416666666667, 7: 0.5947916666666667, 8: 0.5833333333333334, 9: 0.5677083333333334, 10: 0.5520833333333334}

nb_test_acc_sp =  {0: 0.5625, 0.05: 0.5541666666666667, 0.1: 0.5541666666666667, 0.15: 0.5625, 0.2: 0.55, 0.25: 0.5458333333333333, 0.3: 0.5291666666666667, 0.35: 0.5041666666666667, 0.4: 0.4583333333333333, 0.45: 0.425, 0.5: 0.425}
nb_train_acc_sp =  {0: 0.6166666666666667, 0.05: 0.6197916666666666, 0.1: 0.6208333333333333, 0.15: 0.6229166666666667, 0.2: 0.6145833333333334, 0.25: 0.6072916666666667, 0.3: 0.5854166666666667, 0.35: 0.5479166666666667, 0.4: 0.5083333333333333, 0.45: 0.478125, 0.5: 0.46458333333333335}



print("Gaussian")
print("Train: ",(1-nb_train_acc_gaussian[0.1])/nb_train_acc_gaussian[0])
print("Test: ", (1-nb_test_acc_gaussian[0.1])/nb_test_acc_gaussian[0])
print()
print("Impulse")
print("Train: ",(1-nb_train_acc_sp[0.5])/nb_train_acc_sp[0])
print("Test: ",(1-nb_test_acc_sp[0.5])/nb_test_acc_sp[0])
print()
print("Blur")
print("Train: ",(1-nb_train_acc_blur[10])/nb_train_acc_blur[1])
print("Test: ",(1-nb_test_acc_blur[10])/nb_test_acc_blur[1])
# Out:
# Gaussian
# Train:  0.6486486486486487
# Test:  0.8222222222222223
#
# Impulse
# Train:  0.8682432432432432
# Test:  1.0222222222222221
#
# Blur
# Train:  0.7263513513513512
# Test:  0.8740740740740741

# %%
rf_accuracy_test_gaussian = {0: 0.7333333333333333, 0.01: 0.7458333333333333, 0.02: 0.7291666666666666, 0.03: 0.7041666666666667, 0.04: 0.7125, 0.05: 0.7166666666666667, 0.06: 0.675, 0.07: 0.6625, 0.08: 0.6541666666666667, 0.09: 0.6833333333333333, 0.1: 0.625}
rf_accuracy_train_gaussian = {0: 0.9791666666666666, 0.01: 0.9, 0.02: 0.8645833333333334, 0.03: 0.8604166666666667, 0.04: 0.8208333333333333, 0.05: 0.8208333333333333, 0.06: 0.7885416666666667, 0.07: 0.7989583333333333, 0.08: 0.7677083333333333, 0.09: 0.7447916666666666, 0.1: 0.728125}

rf_accuracy_test_blur = {1: 0.7333333333333333, 2: 0.7375, 3: 0.75, 4: 0.7375, 5: 0.7166666666666667, 6: 0.6791666666666667, 7: 0.6666666666666666, 8: 0.6625, 9: 0.6541666666666667, 10: 0.6541666666666667}
rf_accuracy_train_blur = {1: 0.9791666666666666, 2: 0.9322916666666666, 3: 0.928125, 4: 0.9, 5: 0.865625, 6: 0.809375, 7: 0.7979166666666667, 8: 0.7802083333333333, 9: 0.7708333333333334, 10: 0.7583333333333333}

rf_accuracy_test_sp = {0: 0.7333333333333333, 0.05: 0.75, 0.1: 0.7291666666666666, 0.15: 0.725, 0.2: 0.7458333333333333, 0.25: 0.7375, 0.3: 0.7, 0.35: 0.6708333333333333, 0.4: 0.675, 0.45: 0.6, 0.5: 0.49583333333333335}
rf_accuracy_train_sp = {0: 0.9791666666666666, 0.05: 0.9760416666666667, 0.1: 0.9708333333333333, 0.15: 0.9666666666666667, 0.2: 0.953125, 0.25: 0.9427083333333334, 0.3: 0.9333333333333333, 0.35: 0.9052083333333333, 0.4: 0.86875, 0.45: 0.7885416666666667, 0.5: 0.6625}


print("Gaussian")
print("Train: ", (1-rf_accuracy_train_gaussian[0.1])/rf_accuracy_train_gaussian[0])
print("Test: ",(1-rf_accuracy_test_gaussian[0.1])/rf_accuracy_test_gaussian[0])
print()
print("Impulse")
print("Train: ",(1-rf_accuracy_train_sp[0.5])/rf_accuracy_train_sp[0])
print("Test: ",(1-rf_accuracy_test_sp[0.5])/rf_accuracy_test_sp[0])
print()
print("Blur")
print("Train: ",(1-rf_accuracy_train_blur[10])/rf_accuracy_train_blur[1])
print("Test: ",(1-rf_accuracy_test_blur[10])/rf_accuracy_test_blur[1])
# Out:
# Gaussian
# Train:  0.2776595744680851
# Test:  0.5113636363636364
#
# Impulse
# Train:  0.34468085106382984
# Test:  0.6875
#
# Blur
# Train:  0.24680851063829792
# Test:  0.4715909090909091
